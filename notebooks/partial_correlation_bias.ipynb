# %%
import numpy as np
import polars as pl

from climate_attitudes.correlation import Correlation

# %%
rng = np.random.default_rng(202603131007)

# %%
x = rng.normal(size=10)
y = rng.normal(size=10)
z = x + y + rng.normal(scale=0.25, size=10)
df = pl.DataFrame(dict(x=x, y=y, z=z))

# %%
Correlation.PARTIAL.calculate(df)
